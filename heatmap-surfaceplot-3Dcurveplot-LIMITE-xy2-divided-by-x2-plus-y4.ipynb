# %% [markdown]
# ### Exemplo 14.2.3

# %% [markdown]
# <b>Referência:</b> Cálculo Vol. 2 - James Stewart - Tradução da 6ª edição norte americana

# %% [markdown]
# $$f(x,y) = \frac{xy^2}{x^2 + y^4}$$

# %%
import numpy as np

def f(x, y):
    try:
        return (x * y ** 2 ) / (x ** 2 + y ** 4)
    except:
        return np.nan
    
z = np.zeros((41,41))
x = np.arange(-2, 2.1, 0.1)
y = np.arange(-2, 2.1, 0.1)

for i in range(len(x)):
    for j in range(len(y)):
        z[i][j] = f(x[i], y[j])
        
z[20][20] = np.nan # correção devido erro de arrendondamento

# %% [markdown]
# Vejamos agora o heatmap:

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))

xtickpositions = list(map(lambda x: x + 0.5, range(0,41)))
xticklabels = list(map(lambda t: round(t,2), y))
ytickpositions = list(map(lambda x: x + 0.5, range(0,41)))
yticklabels = list(map(lambda t: round(t,2), y))

ax = sns.heatmap(
    z, 
    linewidths=.5, 
)
plt.xticks(xtickpositions, xticklabels)
plt.yticks(ytickpositions, yticklabels, rotation="horizontal")
plt.show()

# %%
import numpy as np

def f(x, y):
    try:
        return (x * y ** 2 ) / (x ** 2 + y ** 4)
    except:
        return np.nan
    
z = np.zeros((51,51))
x = np.arange(-0.5, 0.51, 0.02)
y = np.arange(-0.5, 0.51, 0.02)

for i in range(len(x)):
    for j in range(len(y)):
        z[i][j] = f(x[i], y[j])
        
z[25][25] = np.nan # correção devido erro de arrendondamento

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))

ax = sns.heatmap(
    z, 
    linewidths=.5, 
)
plt.xticks([])
plt.yticks([])

plt.show()
