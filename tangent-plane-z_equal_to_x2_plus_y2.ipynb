# %% [markdown]
# <h1>Plano tangente</h1>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from IPython.display import clear_output

for angle in range(30,330,10):
    fig = plt.figure() # janela
    ax = fig.gca(projection='3d') # eixos 3D    
    
    X = np.arange(-2, 2, 0.1) # X variando de 100 a 150 de 2 em 2
    Y = np.arange(-2, 2, 0.1) # Y variando de 100 a 190 de 3 em 3
    X, Y = np.meshgrid(X, Y) # criando a grade de pontos
    Z = X + Y - 0.5 # calculando Z

    # alpha é a transparência da superfície
    surf = ax.plot_surface(X, Y, Z, alpha=0.2) # gráfico de superfície

    X = np.arange(-2, 2, 0.1) # X variando de 100 a 150 de 2 em 2
    Y = np.arange(-2, 2, 0.1) # Y variando de 100 a 190 de 3 em 3
    X, Y = np.meshgrid(X, Y) # criando a grade de pontos
    Z = X**2 + Y**2 # calculando Z

    # alpha é a transparência da superfície
    surf = ax.plot_surface(X, Y, Z, alpha=0.2, color='r') # gráfico de superfície

    ax.view_init(0, angle) # ângulos para apresentação do gráfico

    plt.tight_layout()
    plt.gca()
    clear_output(wait=True)
    plt.show()
